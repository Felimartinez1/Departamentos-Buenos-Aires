# %%
import pandas as pd

### leer el csv de detalles_remax.csv
pd.read_csv("../data/detalles_remax.csv", sep=";")
# Out:
#                                                Título Valor Alquiler  \
# 0    Alquiler 3 Amb. en Palermo - Frente Muy Luminoso    800.000 ARS
# 1    ALQUILER AMPLIO 3 AMBIENTES/AMENITIES V. URQUIZA  1.150.000 ARS
# 2   Alquiler departamento 2 ambientes en Villa Urq...    550.000 ARS
# 3    Alquiler Dpto 2 amb / balcon Amenities Caballito    700.000 ARS
# 4                  ALQUILER 3 AMBIENTES VILLA ORTUZAR        950 USD
# 5            ALQUILER EXCELENTE MONOAMBIENTE PATERNAL    420.000 USD
# 6   ALQUILER DEPTO 4 AMB CON BALCON ATERRAZADO GRANDE    950.000 ARS
# 7     ALQUILER DEPARTAMENTO 2 AMBIENTES ZONA ALMAGRO.    600.000 USD
# 8   Departamento en Alquiler 2 ambientes Villa crespo    420.000 ARS
# 9   ALQUILER DEPARTAMENTO 2 AMBIENTES VILLA SANTA ...    600.000 ARS
# 10  DEPARTAMENTO ALQUILER 2 AMBIENTES BELGRANO TER...    650.000 ARS
# 11  Alquiler Monoambiente Amueblado  40 mts en Pal...    600.000 ARS
# 12  Alquiler Departamento 2 ambientes en Puerto Ma...      3.800 USD
# ...

# %%
import pandas as pd

### leer el csv de detalles_remax.csv
pd.read_csv("../data/detalles_zona.csv", sep=";")
# Out:
#                                                Título       Valor Alquiler  \
# 0   2 Ambientes con Cochera en Torre Montañeses. e...    alquilerUSD 1.100
# 1                          Departamento - Las Cañitas      alquilerUSD 850
# 2   Alquiler Departamento 3 Dorm. 2 Cocheras Paler...    alquilerUSD 6.000
# 3                          Ayacucho y Pacheco de Melo    alquilerUSD 1.300
# 4   2 Ambientes Contrafrente con Balcón en Palermo...    alquiler$ 590.000
# 5      Monoambiente en 1er Piso con Balcon Al Frente!    alquiler$ 490.000
# 6   Amplio Depto de 6 Amb - Cochera Fija en Palerm...    alquilerUSD 1.500
# 7                   Departamento en Palermo Hollywood      alquilerUSD 550
# 8                  Alquiler en Recoleta - Sin Muebles      alquilerUSD 900
# 9   La Porteña Residences - Puerto Madero Alquiler...    alquilerUSD 2.300
# 10  2 Ambientes Amoblado y Equipado en Torre Vista...    alquilerUSD 1.400
# ...
